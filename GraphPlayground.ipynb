# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.Graph() # G is an empty Graph

# %%
G.add_nodes_from(range(9))
G.add_edges_from([(0,1), (0,2), (1,3), (1,4), (1,7), (2,5), (2,8), (3, 4), (3,5),(4,6), (4,7), (4,8), (5,7)])

# %%
nx.draw(G, node_color='c',edge_color='k', with_labels=True)

# %%
import DirectedGraph
import UndirectedGraph
import GraphTraversals as gt

# %%
g = UndirectedGraph.UndirectedGraph()
g.add_vertices(range(9))
g.add_edges([(0,1), (0,2), (1,3), (1,4), (1,7), (2,5), (2,8), (3, 4), (3,5), (4,6), (4,7), (4,8), (5,7)])

# print(g)
# g.remove_vertex(1)
# print(g)
# g.remove_vertex(8)
# print(g)

print(gt.RDFS(g, 6))
print(gt.IDFS(g, 6))
print(gt.BFS(g, 6))
# Out:
# [6, 4, 1, 0, 2, 5, 3, 7, 8]
# [6, 4, 1, 0, 2, 5, 3, 7, 8]
# [6, 4, 1, 3, 7, 8, 0, 5, 2]
